# %% [markdown]
# # cek

# %%
import networkx as nx
import matplotlib.pyplot as plt

# G = nx.Graph([(0, 1), (0, 2), (0, 3), (1, 2), (1, 3)])

g = nx.Graph()

g.nodes()

g.add_edge(9, 7)
g.add_edge(7, 5)
g.add_edge(7, 8)
g.add_edge(7, 6)
g.add_edge(8, 5)
g.add_edge(8, 6)
g.add_edge(6, 5)
g.add_edge(6, 4)
g.add_edge(5, 4)
g.add_edge(4, 3)
g.add_edge(4, 1)
g.add_edge(3, 1)
g.add_edge(2, 3)
g.add_edge(2, 1)

# nx.draw(g)
nx.draw(g, with_labels = True)

print("Degree centrality: \n", nx.degree_centrality(g))
print("Closeness centrality: \n", nx.closeness_centrality(g))
print("Beetweeness centrality: \n", nx.betweenness_centrality(g))
# plt.savefig("filename.png")
plt.show()
# Out:
# Degree centrality:
#  {9: 0.125, 7: 0.5, 5: 0.5, 8: 0.375, 6: 0.5, 4: 0.5, 3: 0.375, 1: 0.375, 2: 0.25}
# Closeness centrality:
#  {9: 0.34782608695652173, 7: 0.5, 5: 0.6153846153846154, 8: 0.47058823529411764, 6: 0.6153846153846154, 4: 0.6153846153846154, 3: 0.47058823529411764, 1: 0.47058823529411764, 2: 0.34782608695652173}
# Beetweeness centrality:
#  {9: 0.0, 7: 0.25, 5: 0.21428571428571427, 8: 0.0, 6: 0.21428571428571427, 4: 0.5357142857142857, 3: 0.10714285714285714, 1: 0.10714285714285714, 2: 0.0}
